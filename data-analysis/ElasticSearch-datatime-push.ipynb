# %% [markdown]
# # Xen Code Review Kibana-dashboard builder

# %% [markdown]
# This notebook aims at building a Kibana dashboard focused on the several aspects of interest for the Xen community.
#
# This builds the following panels:
# * Time-focused panel at the level of patch series
# * People/Organizations panel at the level of patches/comments/reviews
# * Backlog/commits panel at the level of patch series

# %%
# Elastic search library
from elasticsearch import Elasticsearch
# python-mysql database access
import MySQLdb
import logging
import pandas
from ConfigParser import ConfigParser

# %%
config = ConfigParser()
config.read("settings")

args = {}
# There are two sections: mysql and elasticsearch
if config.has_section("mysql"):
    if config.has_option("mysql", "user") and \
        config.has_option("mysql", "password") and \
        config.has_option("mysql", "mlstats_db") and \
        config.has_option("mysql", "cvsanaly_db") and \
        config.has_option("mysql", "code_review_db"):
        args["mysql"] = dict(config.items("mysql"))

if config.has_section("elasticsearch"):
    if config.has_option("elasticsearch", "user") and \
       config.has_option("elasticsearch", "password") and \
       config.has_option("elasticsearch", "host") and \
       config.has_option("elasticsearch", "port") and \
       config.has_option("elasticsearch", "path"):
         args["elasticsearch"] = dict(config.items("elasticsearch"))

if not(args.has_key("mysql") and args.has_key("elasticsearch")):
    raise Exception("Section 'mysql' or section 'elasticsearch' not found in the 'settings' file")

# %%
def connect(args):
   user = args["mysql"]["user"]
   password = args["mysql"]["user"]
   host = "localhost"
   db = args["mysql"]["code_review_db"]

   try:
      db = MySQLdb.connect(user = user, passwd = password, db = db, charset='utf8')
      return db, db.cursor()
   except:
      logging.error("Database connection error")
      raise


def execute_query(connector, query):
   results = int (connector.execute(query))
   cont = 0
   if results > 0:
      result1 = connector.fetchall()
      return result1
   else:
      return []
    

db, cursor = connect(args)

# %%
# Insert data in ElasticSearch
def to_json(row, columns):
    # Function that translates from tuple to JSON doc
    doc = {}
    
    for column in columns:
       
        value = row[columns.index(column) + 1] 
       
        try:
            doc[column] = value
        except:
            doc[column] = ""
   
    return doc

# %% [markdown]
# ## Time focused panel

# %% [markdown]
# This panel plays with the following data:
# * Filters:
#  * Patches per patch serie
#  * Loops per patch serie
# * Evolutionary charts:
#  * Time to merge
#  * Time to commit
#  * Time to re-work a patch serie
#  * Cycle time
#  * TIme to first review

# %%
# Calculating the list of patch series found in the database
# Basic info about a patch serie:
#   * Patch Serie id
#   * Patch Serie subject
#   * Patch Serie sender
#   * Patch Serie initial sending date
#   * Patch Serie number of patches
#   * Patch Serie number of versions
#   * Patch Serie number of comments
#   * Patch Serie participants (people commenting)
#   * Patch Serie time 2 merge
#   * Patch Serie merge time
query_patchserie = """ SELECT ps.id as patchserie_id,
                   ps.message_id as message_id,
                   ps.subject as patchserie_subject,
                   pe.email as patchserie_sender,
                   SUBSTRING_INDEX(pe.email, '@', -1) as sender_domain,
                   MIN(psv.date_utc) as patchserie_sent_date,
                   max(t1.patches) as patchserie_numpatches,
                   COUNT(DISTINCT(version)) as patchserie_versions,
                   count(distinct(c.id)) as patchserie_comments,
                   COUNT(DISTINCT(c.submitter_id)) as patchserie_commenters
            FROM patch_series ps,
                 patch_series_version psv,
                 patches p,
                 people pe,
                 comments c,
                 (SELECT psv.ps_id, 
                             p.ps_version_id, 
                             count(distinct(p.id)) as patches 
                  FROM patch_series_version psv, 
                           patches p 
                  WHERE psv.id = p.ps_version_id  
                  GROUP BY psv.ps_id, 
                           p.ps_version_id) t1
            WHERE ps.id = psv.ps_id AND
                  psv.id = p.ps_version_id AND
                  p.ps_version_id = t1.ps_version_id AND
                  p.id = c.patch_id AND
                  p.submitter_id = pe.id
            GROUP BY ps.id
            """


# Calculating the time to merge. Later merging result with previous query
query_time2merge = """ SELECT psv.ps_id as patch_serie,
                   TIMESTAMPDIFF(SECOND, MIN(psv.date_utc), MAX(c.committer_date_utc)) as time2merge,
                   MIN(psv.date_utc) as first_patch_date,
                   MAX(c.committer_date_utc) as merge_time
            FROM patch_series_version psv,
                 patches p,
                 commits c
            WHERE psv.id=p.ps_version_id AND 
                  p.commit_id = c.id 
            GROUP BY psv.ps_id; """

# Calculating the time to commit
query_time2commit = """ SELECT psv.ps_id as patch_serie,
                   TIMESTAMPDIFF(SECOND, MAX(c.date_utc), MAX(commits.committer_date_utc)) as time2commit,
                   MAX(c.date_utc) as last_comment_date, 
                   MAX(commits.committer_date_utc) as commit_time 
            FROM patch_series_version psv, 
                 patches p, 
                 comments c, 
                 commits 
            WHERE psv.id = p.ps_version_id AND 
                  p.commit_id = commits.id AND 
                  p.id=c.patch_id 
            GROUP BY psv.ps_id
            HAVING time2commit >= 0 and time2commit < 2000*3600*24 """

# %%
patchserie_data = execute_query(cursor, query_patchserie)
time2merge_data = execute_query(cursor, query_time2merge)
time2commit_data = execute_query(cursor, query_time2commit)

# %%
patchseries_list = list(patchserie_data)
time2merge_list = list(time2merge_data)
time2commit_list = list(time2commit_data)

# %%
patchseries_df = pandas.DataFrame(patchseries_list, columns=["patchserie_id", "message_id", "subject", "sender", "sender_domain", "sent_date", "num_patches", "num_versions", "num_comments", "num_commenters"])
time2merge_df = pandas.DataFrame(time2merge_list, columns=["patchserie_id", "time2merge", "sent_date", "mergetime"])
time2commit_df = pandas.DataFrame(time2commit_list, columns=["patchserie_id", "time2commit", "lastcommentdate", "committime"])

# %%
patchseries_df = pandas.merge(patchseries_df, time2merge_df, on="patchserie_id", how="left")
patchseries_df = pandas.merge(patchseries_df, time2commit_df, on="patchserie_id", how="left")

# %%
patchseries_df = patchseries_df.fillna(-1)
#patchseries_df

# %%
patchseries_df.columns
# Out:
# Index([u'patchserie_id', u'message_id', u'subject', u'sender', u'sender_domain', u'sent_date_x', u'num_patches', u'num_versions', u'num_comments', u'num_commenters', u'time2merge', u'sent_date_y', u'mergetime', u'time2commit', u'lastcommentdate', u'committime'], dtype='object')

# %%
patchseries_df
# Out:
#       patchserie_id                                         message_id  \
# 0                 6      <4B4344040200007800028412@vpn.id2.novell.com>
# 1                 8  <ED3036A092A28F4C91B0B4360DD128EA3059B708@shzs...
# 2                 9  <de76405a1001060419x714c215fo8b2cc1c134627ae4@...
# 3                10      <4B44BBF30200007800028783@vpn.id2.novell.com>
# 4                12  <de76405a1001070713p543ed648p6e0469bade818ed7@...
# 5                22                   <20100108082904.GA31397@ub-qhe2>
# 6                26       <201001111809.38345.Christoph.Egger@amd.com>
# 7                34                         <4B4CA391.2040005@amd.com>
# 8                42  <alpine.DEB.2.00.1001141718550.27920@kaball-de...
# 9                44                         <4B506D7F.1050500@amd.com>
# 10               45                      <4B5096EB.4090901@oracle.com>
# 11               47      <4B5443BC020000780002A81E@vpn.id2.novell.com>
# 12               52   <20100119095250.GB20691@joejin-pc.cn.oracle.com>
# 13               53  <6CADD16F56BC954D8E28F3836FA7ED7112A9AB19BD@sh...
# 14               54   <20100121004658.GA28792@joejin-pc.cn.oracle.com>
# 15               57  <60E426D47DE8EA47AA104E65008A100D14458756F3@sh...
# 16               64  <6CADD16F56BC954D8E28F3836FA7ED711313B899A0@sh...
# 17               66                  <4B59CCB1.8050504@tycho.ncsc.mil>
# 18               68  <ED3036A092A28F4C91B0B4360DD128EA35C4D5A1@shzs...
# 19               70        <7kockhxvc2.fsf@pingu.sky.yk.fujitsu.co.jp>
# 20               72  <EB8593BCECAB3D40A8248BE0B6400A3835A434DD@shzs...
# 21               73  <EB8593BCECAB3D40A8248BE0B6400A3835A4384E@shzs...
# 22               74       <201001271417.51234.Christoph.Egger@amd.com>
# 23               76  <C8EDE645B81E5141A8C6B2F73FD9265117C58A3367@sh...
# 24               77  <C8EDE645B81E5141A8C6B2F73FD9265117C58A3365@sh...
# 25               79  <C8EDE645B81E5141A8C6B2F73FD9265117C58A3368@sh...
# 26               83                     <4B621D41.5030805@scsiguy.com>
# 27               84  <C8EDE645B81E5141A8C6B2F73FD9265117C58A35F4@sh...
# 28               85  <C8EDE645B81E5141A8C6B2F73FD9265117C58A35FD@sh...
# 29               86    <C7731B80-57B6-4E0D-86F9-824709736047@rice.edu>
# ...             ...                                                ...
# 7287           9566  <1455705264-17744-1-git-send-email-ian.campbel...
# 7288           9569  <1455726686-23091-1-git-send-email-konrad.wilk...
# 7289           9570  <1455717855-2344-1-git-send-email-ian.campbell...
# 7290           9571  <1455719438-11095-1-git-send-email-ian.campbel...
# 7291           9572  <1455720074-11321-1-git-send-email-ian.campbel...
# 7292           9573  <1455721113-11540-1-git-send-email-ian.campbel...
# 7293           9574  <1455723595-30904-1-git-send-email-ian.campbel...
# 7294           9576  <1455738711-32328-1-git-send-email-andrew.coop...
# 7295           9577  <1455741740-11469-1-git-send-email-andrew.coop...
# 7296           9578  <1455764256-8700-1-git-send-email-cardoe@cardo...
# 7297           9579  <1455793357-5712-1-git-send-email-ian.campbell...
# 7298           9580  <1455798403-21953-1-git-send-email-andrew.coop...
# 7299           9581  <1455792328-28855-1-git-send-email-czuzu@bitde...
# 7300           9582  <1455792823-29003-1-git-send-email-czuzu@bitde...
# 7301           9583  <1455806185-29539-1-git-send-email-andrew.coop...
# 7302           9584  <1455830545-848-1-git-send-email-cardoe@cardoe...
# 7303           9586  <1455818622-30625-1-git-send-email-andrew.coop...
# 7304           9587  <1455824116-13783-1-git-send-email-czuzu@bitde...
# 7305           9588  <1455833409-19139-1-git-send-email-andrew.coop...
# 7306           9589  <1455887316-9223-1-git-send-email-mcgrof@kerne...
# 7307           9591  <1455877704-44419-1-git-send-email-roger.pau@c...
# 7308           9592  <1455882291-1867-1-git-send-email-ian.campbell...
# 7309           9593  <1455911749-89579-1-git-send-email-cardoe@card...
# 7310           9599  <1455931646-5672-1-git-send-email-arei.gonglei...
# 7311           9600  <1455982445-19054-1-git-send-email-cardoe@card...
# 7312           9601  <1461418307-5845-1-git-send-email-wei.w.wang@i...
# 7313           9604  <1461419854-5968-1-git-send-email-wei.w.wang@i...
# 7314           9606  <1461419875-6050-1-git-send-email-wei.w.wang@i...
# 7315           9607  <1461419884-6091-1-git-send-email-wei.w.wang@i...
# 7316           9610  <1461419914-6214-1-git-send-email-wei.w.wang@i...
#
#                                                 subject  \
# 0     linux/privcmd: fix for proper operation in com...
# 1     xend: passthrough: also do_FLR when a device i...
# 2        Handle PoD case in hvm_hap_nested_page_fault()
# 3                    x86: fix NUMA handling (c/s 20599)
# 4                              Per-cpu xentrace buffers
# 5                    xend: fix options for assigned pci
# 6                  [TOOLS] blktap: make memshr optional
# 7             numa: fix problems with memory-less nodes
# 8              implement xc_map_foreign_bulk for minios
# 9         xend: Fix non-contiguous NUMA node assignment
# 10          Change default cpufreq governor to ondemand
# 11    linux/blkfront: fixes for 'xm block-detach ......
# 12                   Fix blkback/blktap sysfs read bug.
# 13    Change vcpu_avail type to hex string when pass...
# 14                         Fix blk{back,tap} sysfs race
# 15                 VT-d: improve RMRR validity checking
# 16    [VT-d] Dis-allow PCI device assignment if PoD ...
# 17    tools/ Exposes Flask XSM AVC functions to user...
# 18    x86: check if desc->action is NULL when unbind...
# 19    xend: destroy restored domain when its device ...
# 20    enhancement for unmaskable MSI and two cosmeti...
# 21           HVM vcpu hotplug: Fix acpi method NTFY bug
# 22        svm: Fix migration in the middle of a syscall
# 23                 MCE:  Handle the vMCA bank correctly
# 24    MCE: Not GP fault when guest write non 0s  or ...
# 25    MCE: Fix the vMCE address translation for HVM ...
# 26    iommu-remote: Fix lost serial TX interrupts.  ...
# 27              DOM0: Add Machine check support to dom0
# 28    Dom0: Don't switch back to user space  stack i...
# 29    evtchn_do_upcall: Fix logic to start correctly...
# ...                                                 ...
# 7287  xl: uptime: skip dom0 when calling print_domU_...
# 7288  xen/blback: Fit the important information of t...
# 7289     xl: free config_data on error in domain_create
# 7290  tools: gtracestat: Drop unused functions do_cs...
# 7291                               tools: remove xenpmd
# 7292   xenpaging: do not leak if --pagefile given twice
# 7293  xenpaging: don't try to log via xch if xc_inte...
# 7294           xen: Avoid left shifting into a sign bit
# 7295  [VERY RFC] Clang: Issues with .data.rel.ro rel...
# 7296             xen: add randconfig target to Makefile
# 7297  docs: document handling of metacharacter escap...
# 7298  xen/x86: Annotate deliberate fallthrough cases...
# 7299  x86/hvm_event: fix uninitialized struct field ...
# 7300  x86/monitor: minor left-shift undefined behavi...
# 7301             travis: Drop bridge-utils and iproute2
# 7302  tools/configure: only require bcc/ld86/as86 wh...
# 7303     xen/x86: Map Xen code/data/bss with superpages
# 7304  arm/monitor vm-events: Implement guest-request...
# 7305  hvmloader: Use xen/errno.h rather than the hos...
# 7306  x86/init: replace paravirt_enabled() were poss...
# 7307  x86/PVHv2: add XEN_ prefix to HVM_START_MAGIC_...
# 7308  MAINTAINERS: Drop myself as xen netback mainta...
# 7309       MAINTAINERS: add myself for Travis CI config
# 7310  xen-netfront: set real_num_tx_queues to zreo a...
# 7311                 x86: CONFIG_X86 defined by Kconfig
# 7312             Porting the intel_pstate driver to Xen
# 7313  x86/cpu_hotplug: add the unregister_cpu_notifi...
# 7314  x86/intel_pstate: relocate the driver register...
# 7315  x86/intel_pstate: the main boby of the intel_p...
# 7316  x86/intel_pstate: enable xenpm to control the ...
#
#                                 sender    sender_domain         sent_date_x  \
# 0                  JBeulich@novell.com       novell.com 2010-01-05 12:52:04
# 1                 dexuan.cui@intel.com        intel.com 2010-01-05 15:44:47
# 2                    dunlapg@umich.edu        umich.edu 2010-01-06 12:19:37
# 3                  JBeulich@novell.com       novell.com 2010-01-06 15:36:03
# 4                    dunlapg@umich.edu        umich.edu 2010-01-07 15:13:48
# 5                    qing.he@intel.com        intel.com 2010-01-08 08:29:04
# 6              Christoph.Egger@amd.com          amd.com 2010-01-11 17:09:38
# 7               andre.przywara@amd.com          amd.com 2010-01-12 16:30:09
# 8     stefano.stabellini@eu.citrix.com    eu.citrix.com 2010-01-14 17:33:03
# 9               andre.przywara@amd.com          amd.com 2010-01-15 13:28:31
# 10               john.haxby@oracle.com       oracle.com 2010-01-15 16:25:15
# 11                 JBeulich@novell.com       novell.com 2010-01-18 10:19:24
# 12                  joe.jin@oracle.com       oracle.com 2010-01-19 09:52:50
# 13               dongxiao.xu@intel.com        intel.com 2010-01-20 05:11:28
# 14                  joe.jin@oracle.com       oracle.com 2010-01-21 00:46:58
# 15               weidong.han@intel.com        intel.com 2010-01-21 02:46:12
# 16               dongxiao.xu@intel.com        intel.com 2010-01-21 12:28:13
# 17              mbgrego@tycho.ncsc.mil   tycho.ncsc.mil 2010-01-22 16:05:05
# 18                dexuan.cui@intel.com        intel.com 2010-01-22 08:01:44
# 19                kouya@jp.fujitsu.com   jp.fujitsu.com 2010-01-26 05:56:39
# 20             xiantao.zhang@intel.com        intel.com 2010-01-26 14:10:28
# 21               jinsong.liu@intel.com        intel.com 2010-01-27 05:33:00
# 22             Christoph.Egger@amd.com          amd.com 2010-01-27 13:17:50
# 23             yunhong.jiang@intel.com        intel.com 2010-01-28 05:55:50
# 24             yunhong.jiang@intel.com        intel.com 2010-01-28 05:55:53
# 25             yunhong.jiang@intel.com        intel.com 2010-01-28 05:55:58
# 26                   gibbs@scsiguy.com      scsiguy.com 2010-01-28 23:26:57
# 27             yunhong.jiang@intel.com        intel.com 2010-01-28 10:13:57
# 28             yunhong.jiang@intel.com        intel.com 2010-01-28 10:26:17
# 29                    kaushik@rice.edu         rice.edu 2010-01-29 05:34:42
# ...                                ...              ...                 ...
# 7287           ian.campbell@citrix.com       citrix.com 2016-02-17 10:34:23
# 7288            konrad.wilk@oracle.com       oracle.com 2016-02-17 16:31:26
# 7289           ian.campbell@citrix.com       citrix.com 2016-02-17 14:04:13
# 7290           ian.campbell@citrix.com       citrix.com 2016-02-17 14:30:37
# 7291           ian.campbell@citrix.com       citrix.com 2016-02-17 14:41:14
# 7292           ian.campbell@citrix.com       citrix.com 2016-02-17 14:58:33
# 7293           ian.campbell@citrix.com       citrix.com 2016-02-17 15:39:55
# 7294         andrew.cooper3@citrix.com       citrix.com 2016-02-17 19:51:51
# 7295         andrew.cooper3@citrix.com       citrix.com 2016-02-17 20:42:20
# 7296                 cardoe@cardoe.com       cardoe.com 2016-02-18 02:57:35
# 7297           ian.campbell@citrix.com       citrix.com 2016-02-18 11:02:37
# 7298         andrew.cooper3@citrix.com       citrix.com 2016-02-18 12:26:43
# 7299             czuzu@bitdefender.com  bitdefender.com 2016-02-18 10:45:28
# 7300             czuzu@bitdefender.com  bitdefender.com 2016-02-18 10:53:43
# 7301         andrew.cooper3@citrix.com       citrix.com 2016-02-18 14:36:25
# 7302                 cardoe@cardoe.com       cardoe.com 2016-02-18 21:22:22
# 7303         andrew.cooper3@citrix.com       citrix.com 2016-02-18 18:03:38
# 7304             czuzu@bitdefender.com  bitdefender.com 2016-02-18 19:35:16
# 7305         andrew.cooper3@citrix.com       citrix.com 2016-02-18 22:10:09
# 7306                 mcgrof@kernel.org       kernel.org 2016-02-19 13:08:27
# 7307              roger.pau@citrix.com       citrix.com 2016-02-19 10:28:24
# 7308           ian.campbell@citrix.com       citrix.com 2016-02-19 11:44:51
# 7309                 cardoe@cardoe.com       cardoe.com 2016-02-19 19:55:49
# 7310           arei.gonglei@huawei.com       huawei.com 2016-02-20 01:27:26
# 7311                 cardoe@cardoe.com       cardoe.com 2016-02-20 15:34:04
# 7312                 JBeulich@suse.com         suse.com 2016-04-23 13:31:47
# 7313              wei.w.wang@intel.com        intel.com 2016-05-13 07:50:00
# 7314              wei.w.wang@intel.com        intel.com 2016-05-13 07:50:36
# 7315              wei.w.wang@intel.com        intel.com 2016-04-23 13:58:04
# 7316              wei.w.wang@intel.com        intel.com 2016-05-13 07:51:45
#
#       num_patches  num_versions  num_comments  num_commenters  time2merge  \
# 0               1             1             2               2          -1
# 1               1             1             5               3       59553
# 2               1             1             1               1        1546
# 3               1             1             3               2          -1
# 4               1             1             4               3          -1
# 5               1             1             3               2       11402
# 6               1             1             2               2       49903
# 7               1             1             4               2          -1
# 8               1             1             1               1          -1
# 9               1             1             5               3          -1
# 10              1             1             1               1      178915
# 11              1             1             2               2    17388571
# 12              1             1            16               4          -1
# 13              1             1             4               2          -1
# 14              1             1             1               1          -1
# 15              1             1            75              10      193032
# 16              1             1             3               3          -1
# 17              1             1             1               1          -1
# 18              1             1             2               2       10774
# 19              1             1             2               1       97388
# 20              1             1             4               2          -1
# 21              1             1            11               2          -1
# 22              1             1             1               1          -1
# 23              1             1             4               2       89494
# 24              1             1             4               2       89527
# 25              1             1             5               2       89595
# 26              1             1             5               3          -1
# 27              1             1             2               2          -1
# 28              1             1             6               3          -1
# 29              1             1             4               2          -1
# ...           ...           ...           ...             ...         ...
# 7287            1             1             1               1          -1
# 7288            1             1             2               2          -1
# 7289            1             1             7               2          -1
# 7290            1             1             2               2      180772
# 7291            1             1             3               3          -1
# 7292            1             1             2               1       15831
# 7293            1             1             1               1      176715
# 7294            1             1             1               1          -1
# 7295            1             1             2               2          -1
# 7296            1             1             1               1          -1
# 7297            1             1             4               2          -1
# 7298            1             1             2               2          -1
# 7299            1             1             6               3       12216
# 7300            1             1             1               1       21233
# 7301            1             1             1               1        7904
# 7302            1             2            12               3          -1
# 7303            1             1            10               2          -1
# 7304            1             1            22               6          -1
# 7305            1             1             9               5          -1
# 7306           10             1            11               5          -1
# 7307            1             1             2               2          -1
# 7308            1             1             1               1          -1
# 7309            1             1             1               1          -1
# 7310            1             1             3               3          -1
# 7311            1             1             2               2          -1
# 7312            1             1            26               4          -1
# 7313            1             1             3               2          -1
# 7314            1             1             5               2          -1
# 7315            1             1             5               3          -1
# 7316            1             1             1               1          -1
#
#                        sent_date_y                     mergetime  time2commit  \
# 0    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 1              2010-01-05 15:44:47           2010-01-06 08:17:20           -1
# 2              2010-01-06 12:19:37           2010-01-06 12:45:23           -1
# 3    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 4    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 5              2010-01-08 08:29:04           2010-01-08 11:39:06           -1
# 6              2010-01-11 17:09:38           2010-01-12 07:01:21           -1
# 7    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 8    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 9    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 10             2010-01-15 16:25:15           2010-01-17 18:07:10           -1
# 11             2010-01-18 10:19:24           2010-08-07 16:28:55     13760510
# 12   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 13   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 14   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 15             2010-01-21 02:46:12           2010-01-23 08:23:24           -1
# 16   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 17   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 18             2010-01-22 08:01:44           2010-01-22 11:01:18           -1
# 19             2010-01-26 05:56:39           2010-01-27 08:59:47        25478
# 20   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 21   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 22   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 23             2010-01-28 05:55:50           2010-01-29 06:47:24        13976
# 24             2010-01-28 05:55:53           2010-01-29 06:48:00        14597
# 25             2010-01-28 05:55:58           2010-01-29 06:49:13           -1
# 26   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 27   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 28   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 29   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# ...                            ...                           ...          ...
# 7287 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7288 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7289 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7290           2016-02-17 14:30:37           2016-02-19 16:43:29           -1
# 7291 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7292           2016-02-17 14:58:33           2016-02-17 19:22:24           -1
# 7293           2016-02-17 15:39:55           2016-02-19 16:45:10           -1
# 7294 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7295 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7296 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7297 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7298 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7299           2016-02-18 10:45:28           2016-02-18 14:09:04           -1
# 7300           2016-02-18 10:53:43           2016-02-18 16:47:36         9832
# 7301           2016-02-18 14:36:25           2016-02-18 16:48:09         7083
# 7302 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7303 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7304 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7305 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7306 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7307 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7308 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7309 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7310 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7311 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7312 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7313 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7314 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7315 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
# 7316 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999           -1
#
#                    lastcommentdate                    committime
# 0    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 1    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 2    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 3    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 4    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 5    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 6    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 8    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 9    1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 10   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 11             2010-03-01 10:07:05           2010-08-07 16:28:55
# 12   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 13   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 14   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 15   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 16   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 17   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 18   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 19             2010-01-27 01:55:09           2010-01-27 08:59:47
# 20   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 21   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 22   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 23             2010-01-29 02:54:28           2010-01-29 06:47:24
# 24             2010-01-29 02:44:43           2010-01-29 06:48:00
# 25   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 26   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 27   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 28   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 29   1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# ...                            ...                           ...
# 7287 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7288 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7289 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7290 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7291 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7292 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7293 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7294 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7295 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7296 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7297 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7298 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7299 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7300           2016-02-18 14:03:44           2016-02-18 16:47:36
# 7301           2016-02-18 14:50:06           2016-02-18 16:48:09
# 7302 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7303 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7304 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7305 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7306 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7307 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7308 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7309 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7310 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7311 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7312 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7313 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7314 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7315 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
# 7316 1969-12-31 23:59:59.999999999 1969-12-31 23:59:59.999999999
#
# [7317 rows x 16 columns]

# %%
user = args["elasticsearch"]["user"]
password = args["elasticsearch"]["password"]
host = args["elasticsearch"]["host"]
port = args["elasticsearch"]["port"]
path = args["elasticsearch"]["path"]
connection = "http://" + user + ":" + password + "@" + host + ":" + port + "/" + path

INDEX = 'xen-patchseries-timefocused'

# Building the ES connection
es = Elasticsearch([connection])
#es.indices.create(index=INDEX)

# %%
patchseries_df["time2commit"] = (patchseries_df["time2commit"] / 3600.0) / 24.0
patchseries_df["time2merge"] = (patchseries_df["time2merge"] / 3600.0) / 24.0

columns = patchseries_df.columns.values.tolist()
print columns
for row in patchseries_df.itertuples():
    # Let's insert into ES each tuple found in the dataset

    uniq_id = row[0]
    doc = to_json(row, columns)
    result = es.index(index=INDEX, doc_type='patchserie', id = uniq_id, body=doc)
# Out:
# ['patchserie_id', 'message_id', 'subject', 'sender', 'sender_domain', 'sent_date_x', 'num_patches', 'num_versions', 'num_comments', 'num_commenters', 'time2merge', 'sent_date_y', 'mergetime', 'time2commit', 'lastcommentdate', 'committime']

# %% [markdown]
# ## Developer/Domain Focused-panel [Deprecated]

# %% [markdown]
# This panel is focused on the analysis of the developers, their reviewers, their domains, and the time to merge, time to first review and time to commit.

# %%
exit()
people_query = """ SELECT p.subject as patch_subject,
                          p.message_id as message_id,
                          p.date_utc as patch_sent_date,
                          pe.email as patch_sender,
                          SUBSTRING_INDEX(pe.email, '@', -1) as patch_sender_domain,
                          ps.id as patchserie_id,
                          ps.subject as patchserie_subject,
                          MIN(psv.date_utc) as patchserie_sent_date,
                          t1.email as patch_comment_sender,
                          t1.domain as patch_comment_domain,
                          t1.comment_date as patch_comment_date,
                          TIMESTAMPDIFF(SECOND, p.date_utc, t1.comment_date) as patch_time2comment
                    FROM patch_series ps,
                         patch_series_version psv,
                         patches p,
                         people pe,
                         (select p.id as patch_id,
                                 pe.email as email,
                                 SUBSTRING_INDEX(pe.email, '@', -1) as domain,
                                 c.date_utc as comment_date
                          from patches p,
                               comments c,
                               people pe
                          where c.patch_id = p.id and
                                c.submitter_id = pe.id) t1
                    WHERE ps.id = psv.ps_id AND
                          psv.id = p.ps_version_id AND
                          p.submitter_id = pe.id AND
                          p.id = t1.patch_id
                    GROUP BY p.id; """


#The issue is in the database. All of the TZ must be substracted. So the negative ones will be added (double substraction),
# while the positive ones will be simply substracted. More info at https://www.bitergia.net/redmine/issues/6699

# %%
people_data = execute_query(cursor, people_query)
people_list = list(people_data)
people_df = pandas.DataFrame(people_list, columns=["patch_subject", "patch_message_id", "patch_sent_date", "patch_sender", "patch_sender_domain", "patchserie_id", "patchserie_subject", "patchserie_sent_date", "patch_comment_sender", "patch_comment_domain", "patch_comment_date", "patch_time2comment"])

# %%
INDEX = 'xen-patchseries-peoplefocused'

# Building the ES connection
es = Elasticsearch()
# Creating the openstack-votes index
es.indices.create(index=INDEX)
# Out:
# {u'acknowledged': True}

# %%
people_df["patch_time2comment"] = (people_df["patch_time2comment"] / 3600.0) / 24.0
columns = people_df.columns.values.tolist()
print columns
for row in people_df.itertuples():
    # Let's insert into ES each tuple found in the dataset

    uniq_id = row[0]
    doc = to_json(row, columns)
    result = es.index(index=INDEX, doc_type='patch', id = uniq_id, body=doc)
# Out:
# ['patch_subject', 'patch_sent_date', 'patch_sender', 'patch_sender_domain', 'patchserie_id', 'patchserie_subject', 'patchserie_sent_date', 'patch_comment_sender', 'patch_comment_domain', 'patch_comment_date', 'patch_time2comment']
